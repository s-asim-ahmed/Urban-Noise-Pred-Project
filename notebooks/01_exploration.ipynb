# %% [markdown]
# # Urban Noise Analytics Exploration
#
# This notebook mirrors the scripted workflow for quick dissertation-oriented exploration. Run the data pipeline first so the processed parquet files exist in `data/processed/`.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parents[0]
processed_path = PROJECT_ROOT / 'data' / 'processed' / 'urban_noise_processed.parquet'
df = pd.read_parquet(processed_path)
df.head()

# %%
df.groupby('borough')['noise_level_db'].agg(['mean', 'median', 'max']).sort_values('mean', ascending=False)

# %% [markdown]
# ## Suggested Write-Up Points
#
# - Compare commercial versus park/residential noise distributions.
# - Identify hourly peaks and discuss likely traffic-driven explanations.
# - Relate strong traffic-noise correlation to the feature engineering choices used in the forecasting stage.
